# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('smartphone_cleaned_v2.csv')

# %%
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#     brand_name                            model    price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999.0    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989.0    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499.0    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999.0    81.0    True
# 4       realme               Realme 10 Pro Plus  24999.0    82.0    True
# ..         ...                              ...      ...     ...     ...
# 961   motorola       Motorola Moto Edge S30 Pro  34990.0    83.0    True
# 962      honor                      Honor X8 5G  14990.0    75.0    True
# 963       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990.0    85.0    True
# 964   motorola             Motorola Moto G91 5G  19990.0    80.0    True
# 965    samsung           Samsung Galaxy M52s 5G  24990.0    74.0    True
#
#      has_nfc  has_ir_blaster     processor_name processor_brand  num_cores  \
# 0       True           False  Snapdragon 8 Gen2      snapdragon  Octa Core
# 1      False           False     Snapdragon 695      snapdragon  Octa Core
# 2      False           False        Exynos 1330          exynos  Octa Core
# 3      False           False     Snapdragon 695      snapdragon  Octa Core
# 4      False           False     Dimensity 1080       dimensity  Octa Core
# ..       ...             ...                ...             ...        ...
# 961    False           False  Snapdragon 8 Gen1      snapdragon  Octa Core
# 962    False           False    Snapdragon 480+      snapdragon  Octa Core
# 963     True            True     Dimensity 8100       dimensity  Octa Core
# 964     True           False     Snapdragon 695      snapdragon  Octa Core
# 965    False           False                NaN             NaN  Octa Core
#
#      processor_speed  battery_capacity  fast_charging  ram_capacity  \
# 0               3.20            5000.0          100.0          12.0
# 1               2.20            5000.0           33.0           6.0
# 2               2.40            5000.0           15.0           4.0
# 3               2.20            5000.0            0.0           6.0
# 4               2.60            5000.0           67.0           6.0
# ..               ...               ...            ...           ...
# 961             3.00            5000.0           68.0           8.0
# 962             2.20            5000.0           22.0           6.0
# 963             2.85            5080.0           67.0           8.0
# 964             2.20            5000.0            0.0           6.0
# 965              NaN            5000.0            0.0           8.0
#
#      internal_memory  screen_size  refresh_rate    resolution  \
# 0              256.0         6.70         120.0  1440 x 3216
# 1              128.0         6.59         120.0  1080 x 2412
# 2               64.0         6.60          90.0  1080 x 2408
# 3              128.0         6.55         120.0  1080 x 2400
# 4              128.0         6.70         120.0  1080 x 2412
# ..               ...          ...           ...           ...
# 961            128.0         6.67         120.0  1080 x 2460
# 962            128.0         6.50          60.0   720 x 1600
# 963            256.0         6.60         144.0  1080 x 2460
# 964            128.0         6.80          60.0  1080 x 2400
# 965            128.0         6.50          60.0  1080 x 2400
#
#      num_rear_cameras num_front_cameras       os  primary_camera_rear  \
# 0                   3                 1  android                 50.0
# 1                   3                 1  android                 64.0
# 2                   3                 1  android                 50.0
# 3                   3                 1  android                 50.0
# 4                   3                 1  android                108.0
# ..                ...               ...      ...                  ...
# 961                 3                 1  android                 64.0
# 962                 3                 1  android                 48.0
# 963                 3                 1  android                 64.0
# 964                 3                 1  android                108.0
# 965                 3                 1  android                 64.0
#
#      primary_camera_front extended_memory
# 0                    16.0               0
# 1                    16.0            1 TB
# 2                    13.0            1 TB
# 3                    16.0            1 TB
# 4                    16.0               0
# ..                    ...             ...
# 961                  16.0               0
# 962                   8.0            1 TB
# 963                  16.0               0
# 964                  32.0            1 TB
# 965                  32.0            1 TB
#
# [966 rows x 24 columns]

# %%
df.shape
# Out:
# (966, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   brand_name            966 non-null    object
#  1   model                 966 non-null    object
#  2   price                 966 non-null    float64
#  3   rating                870 non-null    float64
#  4   has_5g                966 non-null    bool
#  5   has_nfc               966 non-null    bool
#  6   has_ir_blaster        966 non-null    bool
#  7   processor_name        946 non-null    object
#  8   processor_brand       946 non-null    object
#  9   num_cores             960 non-null    object
#  10  processor_speed       924 non-null    float64
#  11  battery_capacity      955 non-null    float64
#  12  fast_charging         966 non-null    float64
#  13  ram_capacity          966 non-null    float64
#  14  internal_memory       964 non-null    float64
#  15  screen_size           966 non-null    float64
#  16  refresh_rate          966 non-null    float64
#  17  resolution            966 non-null    object
#  18  num_rear_cameras      966 non-null    int64
#  19  num_front_cameras     966 non-null    object
#  20  os                    966 non-null    object
#  21  primary_camera_rear   966 non-null    float64
#  22  primary_camera_front  963 non-null    float64
#  23  extended_memory       966 non-null    object
# dtypes: bool(3), float64(11), int64(1), object(9)
# memory usage: 161.4+ KB

# %%
df.isnull().sum()
# Out:
# brand_name               0
# model                    0
# price                    0
# rating                  96
# has_5g                   0
# has_nfc                  0
# has_ir_blaster           0
# processor_name          20
# processor_brand         20
# num_cores                6
# processor_speed         42
# battery_capacity        11
# fast_charging            0
# ram_capacity             0
# internal_memory          2
# screen_size              0
# refresh_rate             0
# resolution               0
# num_rear_cameras         0
# num_front_cameras        0
# os                       0
# primary_camera_rear      0
# primary_camera_front     3
# extended_memory          0
# dtype: int64

# %% [markdown]
# ### Stage - I

# %%
# brand name
df['brand_name'].value_counts()
# Out:
# brand_name
# xiaomi       134
# samsung      130
# vivo         111
# realme        97
# oppo          85
# motorola      52
# apple         46
# oneplus       42
# poco          41
# tecno         33
# iqoo          32
# infinix       29
# google        14
# huawei        14
# honor         13
# nokia         13
# itel          10
# sony           9
# asus           6
# nubia          6
# nothing        5
# jio            4
# lava           4
# gionee         3
# micromax       3
# redmi          3
# letv           3
# ikall          3
# doogee         2
# lyf            2
# lenovo         2
# oukitel        2
# zte            2
# leeco          1
# tesla          1
# cola           1
# duoqin         1
# vertu          1
# blu            1
# lg             1
# leitz          1
# tcl            1
# sharp          1
# blackview      1
# Name: count, dtype: int64

# %%
# top 10 phone brands
df['brand_name'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='brand_name'>

# %%
# price col
df['price'].describe()
# Out:
# count       966.000000
# mean      31657.525880
# std       38783.684474
# min        3499.000000
# 25%       12999.000000
# 50%       19990.000000
# 75%       34999.000000
# max      650000.000000
# Name: price, dtype: float64

# %%
sns.histplot(df['price'],kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
df['price'].skew()
# Out:
# np.float64(7.004427889924124)

# %%
sns.boxplot(df[df['price']<200000]['price'])
# Out:
# <Axes: ylabel='price'>

# %%
df[df['price']>200000]
# Out:
#     brand_name                                   model     price  rating  \
# 422      vertu                   Vertu Signature Touch  650000.0    62.0
# 473     huawei        Huawei Mate 50 RS Porsche Design  239999.0    81.0
# 874     xiaomi  Xiaomi Redmi K20 Pro Signature Edition  480000.0    88.0
# 938     huawei        Huawei Mate 30 RS Porsche Design  214990.0     NaN
#
#      has_5g  has_nfc  has_ir_blaster      processor_name processor_brand  \
# 422   False     True           False      Snapdragon 801      snapdragon
# 473   False     True            True  Snapdragon 8+ Gen1      snapdragon
# 874   False     True           False      Snapdragon 855      snapdragon
# 938    True     True            True           Kirin 990           kirin
#
#      num_cores  processor_speed  battery_capacity  fast_charging  \
# 422  Octa Core             1.50            2275.0           -1.0
# 473  Octa Core             3.20            4700.0           66.0
# 874  Octa Core             2.80            4000.0           27.0
# 938  Octa Core             2.86            4500.0            0.0
#
#      ram_capacity  internal_memory  screen_size  refresh_rate    resolution  \
# 422           2.0             64.0         4.70          60.0  1080 x 1920
# 473          12.0            512.0         6.74         120.0  1212 x 2616
# 874           8.0            256.0         6.39          60.0  1080 x 2340
# 938          12.0            512.0         6.53          60.0  1176 x 2400
#
#      num_rear_cameras num_front_cameras                os  \
# 422                 1                 1           android
# 473                 3                 1  Hongmeng OS v3.0
# 874                 3                 1           android
# 938                 4                 2           android
#
#      primary_camera_rear  primary_camera_front extended_memory
# 422                 13.0                   2.1               0
# 473                 50.0                  13.0          256 GB
# 874                 48.0                  20.0               0
# 938                 40.0                  32.0          256 GB

# %%
df['price'].isnull().sum()
# Out:
# np.int64(0)

# %%
# rating col
df['rating'].describe()
# Out:
# count    870.000000
# mean      78.168966
# std        7.385035
# min       60.000000
# 25%       74.000000
# 50%       80.000000
# 75%       84.000000
# max       89.000000
# Name: rating, dtype: float64

# %%
sns.histplot(df['rating'],kde=True)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
df['rating'].skew()
# Out:
# np.float64(-0.6945850816176975)

# %%
sns.boxplot(df['rating'])
# Out:
# <Axes: ylabel='rating'>

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(96)

# %%
df['has_5g']
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 961    True
# 962    True
# 963    True
# 964    True
# 965    True
# Name: has_5g, Length: 966, dtype: bool

# %%
sns.countplot(x=df['has_5g'], palette='summer')
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_27880\2729163203.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['has_5g'], palette='summer')
# <Axes: xlabel='has_5g', ylabel='count'>

# %%
df['has_5g'].value_counts()
# Out:
# has_5g
# True     538
# False    428
# Name: count, dtype: int64

# %%
sns.countplot(x = df['has_nfc'], palette= 'viridis')
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_27880\911591600.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = df['has_nfc'], palette= 'viridis')
# <Axes: xlabel='has_nfc', ylabel='count'>

# %%
df['has_nfc'].value_counts()
# Out:
# has_nfc
# False    583
# True     383
# Name: count, dtype: int64

# %%
sns.countplot(y = df['has_ir_blaster'])
# Out:
# <Axes: xlabel='count', ylabel='has_ir_blaster'>

# %%
df['processor_brand'] = df['processor_brand'].str.replace('sanpdragon','snapdragon')
df['processor_brand'] = df['processor_brand'].str.replace('apple','bionic')
df['processor_brand'] = df['processor_brand'].str.replace('samsung','exynos')

# %%
temp_df = df[df['processor_brand'] == 'qualcomm']

# %%
df.loc[temp_df.index, 'processor_brand'] = 'snapdragon'

# %%
temp_df = df[df['processor_brand'] == 'a13']

# %%
df.loc[temp_df.index, 'processor_brand'] = 'bionic'

# %%
df['processor_brand'].value_counts()
# Out:
# processor_brand
# snapdragon    404
# helio         200
# dimensity     174
# exynos         50
# bionic         45
# unisoc         26
# tiger          24
# google          9
# kirin           6
# spreadtrum      4
# sc9863a         2
# fusion          1
# mediatek        1
# Name: count, dtype: int64

# %%
df[df['processor_brand'].isnull()]
# Out:
#     brand_name                                 model    price  rating  has_5g  \
# 118      tesla                        Tesla Pi Phone  69999.0    83.0    True
# 143        jio                           Jio Phone 3   4499.0     NaN   False
# 186      ikall                         iKall Z19 Pro   8099.0    60.0   False
# 199    samsung                    Samsung Galaxy A13  14450.0    75.0   False
# 305    samsung  Samsung Galaxy A13 (4GB RAM + 128GB)  14999.0    75.0   False
# 311       itel                          itel S16 Pro   6990.0     NaN   False
# 485    samsung                    Samsung Galaxy A15  15990.0    63.0   False
# 517    samsung                    Samsung Galaxy F14  14990.0    67.0   False
# 568    samsung  Samsung Galaxy A13 (6GB RAM + 128GB)  16499.0    78.0   False
# 722      ikall                             iKall Z19   7999.0    61.0   False
# 742      tecno                   Tecno Spark Go 2022   6249.0    61.0   False
# 758       itel                              itel A56   5490.0     NaN   False
# 788    samsung              Samsung Galaxy S23 FE 5G  54999.0    77.0    True
# 789    samsung                Samsung Galaxy M51s 5G  24990.0    72.0    True
# 832     huawei                       Huawei Nova Y61  21990.0    63.0   False
# 897    samsung                    Samsung Galaxy M35  22999.0    74.0   False
# 898    samsung                    Samsung Galaxy A05  12990.0    63.0   False
# 939    samsung                    Samsung Galaxy A11   9990.0    63.0   False
# 951      ikall                             iKall Z18   6799.0    61.0   False
# 965    samsung                Samsung Galaxy M52s 5G  24990.0    74.0    True
#
#      has_nfc  has_ir_blaster processor_name processor_brand  num_cores  \
# 118     True           False            NaN             NaN  Octa Core
# 143    False           False            NaN             NaN  Quad Core
# 186    False           False            NaN             NaN  Quad Core
# 199    False           False            NaN             NaN  Octa Core
# 305    False           False            NaN             NaN  Octa Core
# 311    False           False            NaN             NaN  Quad Core
# 485    False           False            NaN             NaN  Octa Core
# 517     True           False            NaN             NaN  Octa Core
# 568    False           False            NaN             NaN  Octa Core
# 722    False           False            NaN             NaN  Quad Core
# 742    False           False            NaN             NaN  Octa Core
# 758    False           False            NaN             NaN  Quad Core
# 788     True           False            NaN             NaN  Octa Core
# 789    False           False            NaN             NaN  Octa Core
# 832    False           False            NaN             NaN  Octa Core
# 897     True           False            NaN             NaN  Octa Core
# 898    False           False            NaN             NaN  Octa Core
# 939    False           False            NaN             NaN  Octa Core
# 951    False           False            NaN             NaN  Quad Core
# 965    False           False            NaN             NaN  Octa Core
#
#      processor_speed  battery_capacity  fast_charging  ram_capacity  \
# 118              NaN            5000.0          120.0          16.0
# 143              1.4            2800.0           -1.0           2.0
# 186              1.6            5000.0           -1.0           4.0
# 199              2.0            5000.0           25.0           4.0
# 305              2.0            5000.0           25.0           4.0
# 311              1.3            4000.0           -1.0           2.0
# 485              NaN            5000.0            0.0           6.0
# 517              NaN            5000.0           25.0           4.0
# 568              2.0            5000.0           25.0           6.0
# 722              1.6            5000.0           -1.0           4.0
# 742              2.2            5000.0           -1.0           2.0
# 758              1.3            4000.0           -1.0           1.0
# 788              NaN            4500.0            0.0           8.0
# 789              NaN            6000.0            0.0           6.0
# 832              NaN            5000.0           22.0           4.0
# 897              NaN            6000.0            0.0           8.0
# 898              NaN            5000.0           18.0           4.0
# 939              1.8            4000.0           15.0           2.0
# 951              1.3            5000.0           -1.0           4.0
# 965              NaN            5000.0            0.0           8.0
#
#      internal_memory  screen_size  refresh_rate    resolution  \
# 118            512.0         6.73         165.0  1080 x 2448
# 143             64.0         5.00          60.0   720 x 1280
# 186             64.0         6.50          60.0   720 x 1600
# 199             64.0         6.60          60.0  1080 x 2408
# 305            128.0         6.60          60.0  1080 x 2408
# 311             32.0         6.60          60.0   1600 x 720
# 485             64.0         6.50          60.0   720 x 1600
# 517             64.0         6.62          60.0  2408 x 1080
# 568            128.0         6.60          60.0  1080 x 2408
# 722             32.0         6.50          60.0   720 x 1600
# 742             32.0         6.51          60.0   720 x 1600
# 758             16.0         6.00          60.0   720 x 1600
# 788            128.0         6.50          60.0  1080 x 2400
# 789            128.0         6.70          60.0  1080 x 2400
# 832             64.0         6.52          60.0   720 x 1600
# 897            128.0         6.50          60.0  1080 x 2400
# 898             64.0         6.50          60.0   720 x 1560
# 939             32.0         6.40          60.0   720 x 1560
# 951             64.0         6.82          60.0   720 x 1560
# 965            128.0         6.50          60.0  1080 x 2400
#
#      num_rear_cameras num_front_cameras        os  primary_camera_rear  \
# 118                 3                 1   android                 50.0
# 143                 1                 1   android                  5.0
# 186                 1                 1   android                 13.0
# 199                 4                 1   android                 50.0
# 305                 4                 1   android                 50.0
# 311                 3                 1   android                  8.0
# 485                 3                 1   android                 48.0
# 517                 3                 1   android                 50.0
# 568                 4                 1   android                 50.0
# 722                 1                 1   android                 20.0
# 742                 2                 1   android                 13.0
# 758                 2                 1   android                  8.0
# 788                 4                 1   android                 64.0
# 789                 3                 1   android                 64.0
# 832                 3                 1  EMUI v12                 50.0
# 897                 3                 1   android                 64.0
# 898                 2                 1   android                 48.0
# 939                 3                 1   android                 13.0
# 951                 1                 1   android                 20.0
# 965                 3                 1   android                 64.0
#
#      primary_camera_front       extended_memory
# 118                  32.0                     0
# 143                   2.0                128 GB
# 186                   8.0                128 GB
# 199                   8.0                  1 TB
# 305                   8.0                  1 TB
# 311                   8.0                 32 GB
# 485                   8.0                  1 TB
# 517                  16.0                  1 TB
# 568                   8.0                  1 TB
# 722                  13.0                128 GB
# 742                   8.0                256 GB
# 758                   5.0                 32 GB
# 788                  32.0                     0
# 789                  32.0                  1 TB
# 832                   5.0  Memory Card (Hybrid)
# 897                  32.0                  1 TB
# 898                   5.0                  1 TB
# 939                   8.0                512 GB
# 951                  13.0                 64 GB
# 965                  32.0                  1 TB

# %%
df['num_cores'].value_counts()
# Out:
# num_cores
# Octa Core    886
# Hexa Core     39
# Quad Core     35
# Name: count, dtype: int64

# %%
df['processor_speed'].describe()
# Out:
# count    924.000000
# mean       2.421991
# std        0.461575
# min        1.200000
# 25%        2.050000
# 50%        2.300000
# 75%        2.840000
# max        3.220000
# Name: processor_speed, dtype: float64

# %%
sns.displot(kind='kde',data=df,x='processor_speed')

# %%
df['processor_speed'].skew()
# Out:
# np.float64(0.21650007433262813)

# %%
sns.boxplot(x = df['processor_speed'])
# Out:
# <Axes: xlabel='processor_speed'>

# %%
df
# Out:
#     brand_name                            model    price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999.0    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989.0    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499.0    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999.0    81.0    True
# 4       realme               Realme 10 Pro Plus  24999.0    82.0    True
# ..         ...                              ...      ...     ...     ...
# 961   motorola       Motorola Moto Edge S30 Pro  34990.0    83.0    True
# 962      honor                      Honor X8 5G  14990.0    75.0    True
# 963       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990.0    85.0    True
# 964   motorola             Motorola Moto G91 5G  19990.0    80.0    True
# 965    samsung           Samsung Galaxy M52s 5G  24990.0    74.0    True
#
#      has_nfc  has_ir_blaster     processor_name processor_brand  num_cores  \
# 0       True           False  Snapdragon 8 Gen2      snapdragon  Octa Core
# 1      False           False     Snapdragon 695      snapdragon  Octa Core
# 2      False           False        Exynos 1330          exynos  Octa Core
# 3      False           False     Snapdragon 695      snapdragon  Octa Core
# 4      False           False     Dimensity 1080       dimensity  Octa Core
# ..       ...             ...                ...             ...        ...
# 961    False           False  Snapdragon 8 Gen1      snapdragon  Octa Core
# 962    False           False    Snapdragon 480+      snapdragon  Octa Core
# 963     True            True     Dimensity 8100       dimensity  Octa Core
# 964     True           False     Snapdragon 695      snapdragon  Octa Core
# 965    False           False                NaN             NaN  Octa Core
#
#      processor_speed  battery_capacity  fast_charging  ram_capacity  \
# 0               3.20            5000.0          100.0          12.0
# 1               2.20            5000.0           33.0           6.0
# 2               2.40            5000.0           15.0           4.0
# 3               2.20            5000.0            0.0           6.0
# 4               2.60            5000.0           67.0           6.0
# ..               ...               ...            ...           ...
# 961             3.00            5000.0           68.0           8.0
# 962             2.20            5000.0           22.0           6.0
# 963             2.85            5080.0           67.0           8.0
# 964             2.20            5000.0            0.0           6.0
# 965              NaN            5000.0            0.0           8.0
#
#      internal_memory  screen_size  refresh_rate    resolution  \
# 0              256.0         6.70         120.0  1440 x 3216
# 1              128.0         6.59         120.0  1080 x 2412
# 2               64.0         6.60          90.0  1080 x 2408
# 3              128.0         6.55         120.0  1080 x 2400
# 4              128.0         6.70         120.0  1080 x 2412
# ..               ...          ...           ...           ...
# 961            128.0         6.67         120.0  1080 x 2460
# 962            128.0         6.50          60.0   720 x 1600
# 963            256.0         6.60         144.0  1080 x 2460
# 964            128.0         6.80          60.0  1080 x 2400
# 965            128.0         6.50          60.0  1080 x 2400
#
#      num_rear_cameras num_front_cameras       os  primary_camera_rear  \
# 0                   3                 1  android                 50.0
# 1                   3                 1  android                 64.0
# 2                   3                 1  android                 50.0
# 3                   3                 1  android                 50.0
# 4                   3                 1  android                108.0
# ..                ...               ...      ...                  ...
# 961                 3                 1  android                 64.0
# 962                 3                 1  android                 48.0
# 963                 3                 1  android                 64.0
# 964                 3                 1  android                108.0
# 965                 3                 1  android                 64.0
#
#      primary_camera_front extended_memory
# 0                    16.0               0
# 1                    16.0            1 TB
# 2                    13.0            1 TB
# 3                    16.0            1 TB
# 4                    16.0               0
# ..                    ...             ...
# 961                  16.0               0
# 962                   8.0            1 TB
# 963                  16.0               0
# 964                  32.0            1 TB
# 965                  32.0            1 TB
#
# [966 rows x 24 columns]

# %% [markdown]
# ### Stage - II

# %%
df['battery_capacity'].describe()
# Out:
# count      955.000000
# mean      4821.537173
# std        995.322078
# min       1821.000000
# 25%       4500.000000
# 50%       5000.000000
# 75%       5000.000000
# max      22000.000000
# Name: battery_capacity, dtype: float64

# %%
sns.displot(kind='kde',data=df,x='battery_capacity')

# %%
df[df['battery_capacity'] > 7000]
# Out:
#     brand_name         model    price  rating  has_5g  has_nfc  \
# 386    oukitel  Oukitel WP19  29990.0    84.0   False     True
# 831     doogee  Doogee V Max  45999.0    88.0    True    False
# 952    oukitel   Oukitel WP9  25899.0    72.0   False     True
#
#      has_ir_blaster  processor_name processor_brand  num_cores  \
# 386           False       Helio G95           helio  Octa Core
# 831           False  Dimensity 1080       dimensity  Octa Core
# 952           False       Helio P60           helio  Octa Core
#
#      processor_speed  battery_capacity  fast_charging  ram_capacity  \
# 386              2.0           21000.0           33.0           8.0
# 831              2.6           22000.0           33.0          12.0
# 952              2.0            8000.0           -1.0           6.0
#
#      internal_memory  screen_size  refresh_rate    resolution  \
# 386            256.0         6.78          60.0  1080 x 2400
# 831            256.0         6.58         120.0  1080 x 2408
# 952            128.0         5.86          60.0   720 x 1520
#
#      num_rear_cameras num_front_cameras       os  primary_camera_rear  \
# 386                 3                 1  android                 64.0
# 831                 3                 1  android                108.0
# 952                 3                 1  android                 16.0
#
#      primary_camera_front extended_memory
# 386                  16.0   Not Specified
# 831                  32.0            2 TB
# 952                   8.0   Not Specified

# %%
df['fast_charging'].describe()
# Out:
# count    966.000000
# mean      36.111801
# std       36.044905
# min       -1.000000
# 25%       15.000000
# 50%       30.000000
# 75%       65.000000
# max      240.000000
# Name: fast_charging, dtype: float64

# %%
def fast(row):

  if row['fast_charging'] == -1:
    return 0
  else:
    return 1

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'rating', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_name', 'processor_brand', 'num_cores',
#        'processor_speed', 'battery_capacity', 'fast_charging', 'ram_capacity',
#        'internal_memory', 'screen_size', 'refresh_rate', 'resolution',
#        'num_rear_cameras', 'num_front_cameras', 'os', 'primary_camera_rear',
#        'primary_camera_front', 'extended_memory'],
#       dtype='object')

# %%
x = df.apply(fast,axis=1)
df.insert(12,'fast_charging_available',x)

# %%
df['fast_charging'] = df['fast_charging'].apply(lambda x:np.nan if x == 0 or x == -1 else x)

# %%
df.head()
# Out:
#   brand_name                      model    price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999.0    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499.0    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999.0    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999.0    82.0    True    False
#
#    has_ir_blaster     processor_name processor_brand  num_cores  \
# 0           False  Snapdragon 8 Gen2      snapdragon  Octa Core
# 1           False     Snapdragon 695      snapdragon  Octa Core
# 2           False        Exynos 1330          exynos  Octa Core
# 3           False     Snapdragon 695      snapdragon  Octa Core
# 4           False     Dimensity 1080       dimensity  Octa Core
#
#    processor_speed  battery_capacity  fast_charging_available  fast_charging  \
# 0              3.2            5000.0                        1          100.0
# 1              2.2            5000.0                        1           33.0
# 2              2.4            5000.0                        1           15.0
# 3              2.2            5000.0                        1            NaN
# 4              2.6            5000.0                        1           67.0
#
#    ram_capacity  internal_memory  screen_size  refresh_rate    resolution  \
# 0          12.0            256.0         6.70         120.0  1440 x 3216
# 1           6.0            128.0         6.59         120.0  1080 x 2412
# 2           4.0             64.0         6.60          90.0  1080 x 2408
# 3           6.0            128.0         6.55         120.0  1080 x 2400
# 4           6.0            128.0         6.70         120.0  1080 x 2412
#
#    num_rear_cameras num_front_cameras       os  primary_camera_rear  \
# 0                 3                 1  android                 50.0
# 1                 3                 1  android                 64.0
# 2                 3                 1  android                 50.0
# 3                 3                 1  android                 50.0
# 4                 3                 1  android                108.0
#
#    primary_camera_front extended_memory
# 0                  16.0               0
# 1                  16.0            1 TB
# 2                  13.0            1 TB
# 3                  16.0            1 TB
# 4                  16.0               0

# %%
df['ram_capacity'].value_counts()
# Out:
# ram_capacity
# 8.0     329
# 6.0     234
# 4.0     217
# 12.0     84
# 3.0      54
# 2.0      31
# 16.0      8
# 1.0       7
# 18.0      2
# Name: count, dtype: int64

# %%
temp_df = df[df['internal_memory'].isnull()]

# %%
df.loc[temp_df.index,['ram_capacity','internal_memory']] = [[4,64],[4,64]]

# %%
df['internal_memory'].value_counts()
# Out:
# internal_memory
# 128.0     516
# 64.0      193
# 256.0     154
# 32.0       67
# 512.0      19
# 16.0       11
# 1024.0      5
# 8.0         1
# Name: count, dtype: int64

# %%
df['screen_size'].describe()
# Out:
# count    966.000000
# mean       6.532060
# std        0.331988
# min        3.540000
# 25%        6.500000
# 50%        6.570000
# 75%        6.670000
# max        8.030000
# Name: screen_size, dtype: float64

# %%
sns.displot(kind='kde',data=df,x='screen_size')

# %%
df['screen_size'].skew()
# Out:
# np.float64(-2.2115947012498394)

# %%
sns.boxplot(df['screen_size'])
# Out:
# <Axes: ylabel='screen_size'>

# %%
df['extended_memory'].value_counts()
# Out:
# extended_memory
# 0                       348
# 1 TB                    262
# 512 GB                  116
# 256 GB                  100
# Not Specified            88
# Memory Card (Hybrid)     30
# 128 GB                    9
# 2 TB                      6
# 32 GB                     3
# 64 GB                     3
# 1000 GB                   1
# Name: count, dtype: int64

# %%
df['extended_memory_available'] = df['extended_memory'].apply(lambda x:0 if x == '0' else 1)

# %%
def extended_extractor(row):

  if row['extended_memory_available'] == 0:
    return np.nan
  else:
    if row['extended_memory'] == '1 TB':
      return 1024
    elif row['extended_memory'] == '512 GB':
      return 512
    elif row['extended_memory'] == '256 GB':
      return 256
    elif row['extended_memory'] == 'Not Specified':
      return np.nan
    elif row['extended_memory'] == 'Memory Card (Hybrid)':
      return np.nan
    elif row['extended_memory'] == '128 GB':
      return 128
    elif row['extended_memory'] == '2 TB':
      return 2048
    elif row['extended_memory'] == '32 GB':
      return 32
    elif row['extended_memory'] == '64 GB':
      return 64
    elif row['extended_memory'] == '1000 GB':
      return 1000

# %%
def extended_extractor(row):

  if row['extended_memory_available'] == 0:
    return np.nan
  else:
    if row['extended_memory'] == 'Not Specified':
      return np.nan
    elif row['extended_memory'] == 'Memory Card (Hybrid)':
      return np.nan
    else:
      return row['extended_memory']

# %%
df['extended_memory']
# Out:
# 0         0
# 1      1 TB
# 2      1 TB
# 3      1 TB
# 4         0
#        ...
# 961       0
# 962    1 TB
# 963       0
# 964    1 TB
# 965    1 TB
# Name: extended_memory, Length: 966, dtype: object

# %%
x = df.apply(extended_extractor,axis=1).str.replace('\u2009',' ').str.split(' ').str.get(0)

# %%
df['extended_memory_available']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 961    0
# 962    1
# 963    0
# 964    1
# 965    1
# Name: extended_memory_available, Length: 966, dtype: int64

# %%
df['extended_upto'] = x

# %%
df['extended_upto'].value_counts()
# Out:
# extended_upto
# 1       262
# 512     116
# 256     100
# 128       9
# 2         6
# 32        3
# 64        3
# 1000      1
# Name: count, dtype: int64

# %%
def transform(text):

  if text == '1':
    return '1024'
  elif text == '2':
    return '2048'
  elif text == '1000':
    return '1024'
  else:
    return text

# %%
df['extended_upto'] = df['extended_upto'].apply(transform)

# %%
df['os']
# Out:
# 0      android
# 1      android
# 2      android
# 3      android
# 4      android
#         ...
# 961    android
# 962    android
# 963    android
# 964    android
# 965    android
# Name: os, Length: 966, dtype: object

# %%
def os_transform(text):

  if 'Memory' in text:
    return np.nan
  elif 'android' in text:
    return text
  elif 'ios' in text:
    return text
  else:
    return 'other'

# %%
df['os'] = df['os'].apply(os_transform)

# %%
df.head()
# Out:
#   brand_name                      model    price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999.0    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989.0    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499.0    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999.0    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999.0    82.0    True    False
#
#    has_ir_blaster     processor_name processor_brand  num_cores  \
# 0           False  Snapdragon 8 Gen2      snapdragon  Octa Core
# 1           False     Snapdragon 695      snapdragon  Octa Core
# 2           False        Exynos 1330          exynos  Octa Core
# 3           False     Snapdragon 695      snapdragon  Octa Core
# 4           False     Dimensity 1080       dimensity  Octa Core
#
#    processor_speed  battery_capacity  fast_charging_available  fast_charging  \
# 0              3.2            5000.0                        1          100.0
# 1              2.2            5000.0                        1           33.0
# 2              2.4            5000.0                        1           15.0
# 3              2.2            5000.0                        1            NaN
# 4              2.6            5000.0                        1           67.0
#
#    ram_capacity  internal_memory  screen_size  refresh_rate    resolution  \
# 0          12.0            256.0         6.70         120.0  1440 x 3216
# 1           6.0            128.0         6.59         120.0  1080 x 2412
# 2           4.0             64.0         6.60          90.0  1080 x 2408
# 3           6.0            128.0         6.55         120.0  1080 x 2400
# 4           6.0            128.0         6.70         120.0  1080 x 2412
#
#    num_rear_cameras num_front_cameras       os  primary_camera_rear  \
# 0                 3                 1  android                 50.0
# 1                 3                 1  android                 64.0
# 2                 3                 1  android                 50.0
# 3                 3                 1  android                 50.0
# 4                 3                 1  android                108.0
#
#    primary_camera_front extended_memory  extended_memory_available  \
# 0                  16.0               0                          0
# 1                  16.0            1 TB                          1
# 2                  13.0            1 TB                          1
# 3                  16.0            1 TB                          1
# 4                  16.0               0                          0
#
#   extended_upto
# 0           NaN
# 1          1024
# 2          1024
# 3          1024
# 4           NaN

# %%
df['extended_upto'].value_counts()
# Out:
# extended_upto
# 1024    263
# 512     116
# 256     100
# 128       9
# 2048      6
# 32        3
# 64        3
# Name: count, dtype: int64

# %%
df.drop(columns=['processor_name','extended_memory'],inplace=True)

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                        96
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                206
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# resolution                     0
# num_rear_cameras               0
# num_front_cameras              0
# os                             0
# primary_camera_rear            0
# primary_camera_front           3
# extended_memory_available      0
# extended_upto                466
# dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# 84.0    59
# 82.0    57
# 83.0    55
# 75.0    53
# 85.0    50
# 80.0    49
# 86.0    47
# 79.0    45
# 77.0    38
# 78.0    36
# 81.0    35
# 89.0    33
# 87.0    31
# 74.0    30
# 76.0    29
# 88.0    23
# 71.0    21
# 72.0    18
# 69.0    18
# 73.0    16
# 61.0    15
# 66.0    15
# 65.0    14
# 70.0    14
# 68.0    13
# 67.0    13
# 60.0    12
# 62.0    11
# 64.0    10
# 63.0    10
# Name: count, dtype: int64

# %%
df.corr(numeric_only=True)['rating']
# Out:
# price                        0.269289
# rating                       1.000000
# has_5g                       0.597107
# has_nfc                      0.472857
# has_ir_blaster               0.159094
# processor_speed              0.625109
# battery_capacity            -0.009406
# fast_charging_available      0.555565
# fast_charging                0.531564
# ram_capacity                 0.758423
# internal_memory              0.481369
# screen_size                  0.284781
# refresh_rate                 0.616193
# num_rear_cameras             0.525953
# primary_camera_rear          0.568448
# primary_camera_front         0.577418
# extended_memory_available   -0.405771
# Name: rating, dtype: float64

# %% [markdown]
# ### Stage - III

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 966 non-null    object
#  1   model                      966 non-null    object
#  2   price                      966 non-null    float64
#  3   rating                     870 non-null    float64
#  4   has_5g                     966 non-null    bool
#  5   has_nfc                    966 non-null    bool
#  6   has_ir_blaster             966 non-null    bool
#  7   processor_brand            946 non-null    object
#  8   num_cores                  960 non-null    object
#  9   processor_speed            924 non-null    float64
#  10  battery_capacity           955 non-null    float64
#  11  fast_charging_available    966 non-null    int64
#  12  fast_charging              760 non-null    float64
#  13  ram_capacity               966 non-null    float64
#  14  internal_memory            966 non-null    float64
#  15  screen_size                966 non-null    float64
#  16  refresh_rate               966 non-null    float64
#  17  resolution                 966 non-null    object
#  18  num_rear_cameras           966 non-null    int64
#  19  num_front_cameras          966 non-null    object
#  20  os                         966 non-null    object
#  21  primary_camera_rear        966 non-null    float64
#  22  primary_camera_front       963 non-null    float64
#  23  extended_memory_available  966 non-null    int64
#  24  extended_upto              500 non-null    object
# dtypes: bool(3), float64(11), int64(3), object(8)
# memory usage: 169.0+ KB
